# %% [markdown]
# # Results

# %%
import sys
sys.path.insert(0, '..')
from utils import plot_stroke
print(sys.path)
print(sys.version)
# Out:
# ['..', '..', '/home/quantumcoder/anaconda3/envs/torch/lib/python36.zip', '/home/quantumcoder/anaconda3/envs/torch/lib/python3.6', '/home/quantumcoder/anaconda3/envs/torch/lib/python3.6/lib-dynload', '', '/home/quantumcoder/anaconda3/envs/torch/lib/python3.6/site-packages', '/home/quantumcoder/anaconda3/envs/torch/lib/python3.6/site-packages/IPython/extensions', '/home/quantumcoder/.ipython']
# 3.6.7 | packaged by conda-forge | (default, Nov 21 2018, 02:32:25)
# [GCC 4.8.2 20140120 (Red Hat 4.8.2-15)]

# %% [markdown]
# This is what you should modify:

# %%
from models.dummy import load_model, generate_unconditionally, generate_conditionally, recognize_stroke
# unconditional_model = load_model('unconditional_900', 40)
unconditional_model = load_model('unconditional_900_w_noise', 30)
# unconditional_model = load_model('unconditional_400', 30)
# conditional_model = load_model('conditional_400', 25)
conditional_model = load_model('conditional_400_w_noise', 22)

# %% [markdown]
# Please, don't modify anything below.
#
# ### Unconditional generation:

# %%
stroke = generate_unconditionally(unconditional_model)
plot_stroke(stroke)
# Out:
# Length of stroke 437

# %% [markdown]
# ### Conditional generation:

# %%
text = 'welcome to lyrebird'
stroke = generate_conditionally(conditional_model, text)
plot_stroke(stroke)
# Out:
# Length of stroke 437

# %% [markdown]
# ### Handwriting recognition:

# %%
text = recognize_stroke(stroke)
print text
